# %% [markdown]
# # Langchain: Models, Prompts and Output Parsers
#
# ## Outline
# - Direct API calls to OpenAI
# - API calls through LangChain:
#     - Prompts
#     - Models
#     - Output Parsers

# %%
#! pip install python-dotenv
#! pip install openai

# %%
import os
import openai

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key = os.environ['OPENAI_API_KEY']

# %%
llm_model = "gpt-3.5-turbo"

# %%
def get_completion(prompt, model=llm_model):
    if not isinstance(prompt, str):
        raise ValueError("Prompt must be a string")

    messages = [{"role":"user", "content": prompt}]
    response = openai.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message["content"]

# %%
get_completion("What is 1+1?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 get_completion("What is 1+1?")
#
# Cell In[27], line 6, in get_completion(prompt, model)
#       3     raise ValueError("Prompt must be a string")
#       5 messages = [{"role":"user", "content": prompt}]
# ----> 6 response = openai.chat.completions.create(
#       7     model=model,
#       8     messages=messages,
#       9     temperature=0
#      10 )
#      11 return response.choices[0].message["content"]
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_utils/_utils.py:303, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     301             msg = f"Missing required argument: {quote(missing[0])}"
#     302     raise TypeError(msg)
# --> 303 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/resources/chat/completions.py:604, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     557 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     558 def create(
#     559     self,
#    (...)
#     602     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     603 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 604     return self._post(
#     605         "/chat/completions",
#     606         body=maybe_transform(
#     607             {
#     608                 "messages": messages,
#     609                 "model": model,
#     610                 "frequency_penalty": frequency_penalty,
#     611                 "function_call": function_call,
#     612                 "functions": functions,
#     613                 "logit_bias": logit_bias,
#     614                 "max_tokens": max_tokens,
#     615                 "n": n,
#     616                 "presence_penalty": presence_penalty,
#     617                 "response_format": response_format,
#     618                 "seed": seed,
#     619                 "stop": stop,
#     620                 "stream": stream,
#     621                 "temperature": temperature,
#     622                 "tool_choice": tool_choice,
#     623                 "tools": tools,
#     624                 "top_p": top_p,
#     625                 "user": user,
#     626             },
#     627             completion_create_params.CompletionCreateParams,
#     628         ),
#     629         options=make_request_options(
#     630             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     631         ),
#     632         cast_to=ChatCompletion,
#     633         stream=stream or False,
#     634         stream_cls=Stream[ChatCompletionChunk],
#     635     )
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_base_client.py:1088, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1074 def post(
#    1075     self,
#    1076     path: str,
#    (...)
#    1083     stream_cls: type[_StreamT] | None = None,
#    1084 ) -> ResponseT | _StreamT:
#    1085     opts = FinalRequestOptions.construct(
#    1086         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087     )
# -> 1088     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_base_client.py:853, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     844 def request(
#     845     self,
#     846     cast_to: Type[ResponseT],
#    (...)
#     851     stream_cls: type[_StreamT] | None = None,
#     852 ) -> ResponseT | _StreamT:
# --> 853     return self._request(
#     854         cast_to=cast_to,
#     855         options=options,
#     856         stream=stream,
#     857         stream_cls=stream_cls,
#     858         remaining_retries=remaining_retries,
#     859     )
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_base_client.py:916, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914 if retries > 0 and self._should_retry(err.response):
#     915     err.response.close()
# --> 916     return self._retry_request(
#     917         options,
#     918         cast_to,
#     919         retries,
#     920         err.response.headers,
#     921         stream=stream,
#     922         stream_cls=stream_cls,
#     923     )
#     925 # If the response is streamed then we need to explicitly read the response
#     926 # to completion before attempting to access the response text.
#     927 if not err.response.is_closed:
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_base_client.py:958, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     954 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     955 # different thread if necessary.
#     956 time.sleep(timeout)
# --> 958 return self._request(
#     959     options=options,
#     960     cast_to=cast_to,
#     961     remaining_retries=remaining,
#     962     stream=stream,
#     963     stream_cls=stream_cls,
#     964 )
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_base_client.py:916, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914 if retries > 0 and self._should_retry(err.response):
#     915     err.response.close()
# --> 916     return self._retry_request(
#     917         options,
#     918         cast_to,
#     919         retries,
#     920         err.response.headers,
#     921         stream=stream,
#     922         stream_cls=stream_cls,
#     923     )
#     925 # If the response is streamed then we need to explicitly read the response
#     926 # to completion before attempting to access the response text.
#     927 if not err.response.is_closed:
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_base_client.py:958, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     954 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     955 # different thread if necessary.
#     956 time.sleep(timeout)
# --> 958 return self._request(
#     959     options=options,
#     960     cast_to=cast_to,
#     961     remaining_retries=remaining,
#     962     stream=stream,
#     963     stream_cls=stream_cls,
#     964 )
#
# File ~/anaconda3/envs/langchain-app-dev/lib/python3.11/site-packages/openai/_base_client.py:930, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927     if not err.response.is_closed:
#     928         err.response.read()
# --> 930     raise self._make_status_error_from_response(err.response) from None
#     932 return self._process_response(
#     933     cast_to=cast_to,
#     934     options=options,
#    (...)
#     937     stream_cls=stream_cls,
#     938 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
